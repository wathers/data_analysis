# %%
import json

import pandas as pd

# %% [markdown]
# ### 从csv中导入

# %%
df = pd.read_csv('../mock_sales_data.csv')
df
# Out:
#    order_id        date customer region category product  quantity  \
# 0   ORD0001  2025-11-24     徐明先生     华南     电子产品      手机         9
# 1   ORD0002  2025-10-30       张伟     华南     家居用品      台灯         1
# 2   ORD0003  2025-04-12     张伟先生     华北     运动户外      手套         8
# 3   ORD0004  2025-08-05     李娜女士     东北     食品饮料      咖啡         5
# 4   ORD0005  2025-02-19     徐明先生     华东     食品饮料      坚果        20
# ..      ...         ...      ...    ...      ...     ...       ...
# 95  ORD0096  2025-04-30     周丽先生     华南     食品饮料      茶叶        14
# 96  ORD0097  2025-02-06     吴鑫女士     东北     电子产品      耳机        10
# 97  ORD0098  2025-03-05     何勇先生     西南     家居用品      拖鞋        13
# 98  ORD0099  2025-11-03       高洁     华东     电子产品      鼠标        11
# 99  ORD0100  2025-01-11       孙艳     东北     运动户外      背包        19
#
#     unit_price     total status
# 0      1228.23  11054.07    已取消
# 1       473.01    473.01    已完成
# 2      2248.80  17990.40    配送中
# ...

# %% [markdown]
# ### 从json中导入

# %%
# df = pd.read_json('../mock_sales_data.json')
# df
import json
with open('../mock_sales_data.json','r') as f:
    data = json.load(f)
df = pd.DataFrame(data['sales'])
df
# Out:
#    order_id        date customer region category product  quantity  \
# 0   ORD0001  2025-11-24       陈静     华东     电子产品      手机         9
# 1   ORD0002  2025-10-07     赵敏先生     西南     电子产品      鼠标         2
# 2   ORD0003  2025-10-15     周丽先生     东北     服装鞋帽     连衣裙         8
# 3   ORD0004  2025-08-05     马超先生     华东     食品饮料      咖啡         5
# 4   ORD0005  2025-07-03     徐明先生     华中     食品饮料      咖啡         2
# ..      ...         ...      ...    ...      ...     ...       ...
# 95  ORD0096  2025-02-11     杨磊先生     华中     服装鞋帽     羽绒服         6
# 96  ORD0097  2025-11-01       吴鑫     东北     家居用品      拖鞋         2
# 97  ORD0098  2025-04-30       黄强     华南     食品饮料      茶叶        14
# 98  ORD0099  2025-03-14       梁平     东北     电子产品      手机         6
# 99  ORD0100  2025-05-28     胡涛女士     西南     家居用品      抱枕        15
#
#     unit_price     total status
# 0      1228.23  11054.07    待发货
# 1       153.84    307.68    待发货
# 2      2248.80  17990.40    配送中
# ...
